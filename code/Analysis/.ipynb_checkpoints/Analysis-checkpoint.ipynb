# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
import numpy

# %%
#Slater Sept-Nov 2020

# %%
root_dir='/home/jovyan/labs/SlaterFireHydrology';
data_dir=root_dir+'/data';
processed_dir =data_dir+'/Processed';
raw_dir=data_dir+'/Raw';
precip_station='salmonriver'
river='IndianCreek'

# %%
data_file=processed_dir+'/PrecipFlowData.txt'

# %%
df = pd.read_csv(data_file)

# %%
df.head()
# Out:
#          DATE  PRCP_happycamp  TMAX_happycamp  TMIN_happycamp  TOBS_happycamp  \
# 0  2015-01-01             NaN             NaN             NaN             NaN
# 1  2015-01-02             0.0            48.0            17.0            18.0
# 2  2015-01-03             NaN             NaN             NaN             NaN
# 3  2015-01-04             NaN             NaN             NaN             NaN
# 4  2015-01-05             0.0             NaN             NaN            33.0
#
#    PRCP_orleans  PRCP_salmonriver  PRCP_cavejunction  discharge_IndianCreek  \
# 0           NaN               0.0                NaN             310.656250
# 1           NaN               0.0                NaN             290.437500
# 2           NaN               0.0                NaN             272.614583
# 3           NaN               0.0                NaN             257.375000
# 4           NaN               0.0                NaN             244.250000
#
#    gage_ht_IndianCreek  discharge_IndianCreek_daily_change  \
# 0             4.981979                                 NaN
# 1             4.922396                          -20.218750
# 2             4.867604                          -17.822917
# 3             4.817917                          -15.239583
# 4             4.774167                          -13.125000
#
#    discharge_SalmonRiver  gage_ht_SalmonRiver  \
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
#
#    discharge_SalmonRiver_daily_change  discharge_SuckerCreek  \
# 0                                 NaN             167.927083
# 1                                 NaN             157.031250
# 2                                 NaN             145.177083
# 3                                 NaN             135.562500
# 4                                 NaN             129.333333
#
#    gage_ht_SuckerCreek  discharge_SuckerCreek_daily_change  year  month  day
# 0             1.787083                                 NaN  2015      1    1
# 1             1.755104                          -10.895833  2015      1    2
# 2             1.719583                          -11.854167  2015      1    3
# 3             1.688542                           -9.614583  2015      1    4
# 4             1.668854                           -6.229167  2015      1    5

# %%
df['discharge/30'] = df['discharge_IndianCreek']/30
df['discharge_SalmonRiver/100'] = df['discharge_SalmonRiver']/100

# %%
fig, ax = plt.subplots(1,1)
df.plot(x='DATE', y=['PRCP_'+precip_station,'discharge/30'], ax=ax)
#ax.plot(df['DATE'], df['PRCP'])
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
above_freezing_df = df[df['TMIN_happycamp']>0]

# %%
fig, ax = plt.subplots(1,1)
above_freezing_df.plot(x='DATE', y=['PRCP_'+ precip_station,'discharge/30'], ax=ax)
#ax.plot(df['DATE'], df['PRCP'])
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
summer_df = df[(df['month']>6) & (df['month']<12)]

# %%
fig, ax = plt.subplots(1,1)
summer_df.plot(x='DATE', y=['PRCP_'+precip_station,'discharge/30'], ax=ax)
#ax.plot(df['DATE'], df['PRCP'])
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
summer_2016_df = summer_df[summer_df['year']==2016]

# %%
fig, ax = plt.subplots(8,1, figsize=(5,40))
for i in range(7):
    year=2015+i
    summer_df_year = summer_df[summer_df['year']==year]
    summer_df_year.plot(x='DATE', y=['PRCP_'+ precip_station,'discharge/30'], ax=ax[i])
    ax[i].set_title('year=' + str(year))
#ax.plot(df['DATE'], df['PRCP'])

# %%
fig, ax = plt.subplots(8,1, figsize=(5,40))
for i in range(7):
    year=2015+i
    summer_df_year = summer_df[summer_df['year']==year]
    summer_df_year.plot(x='DATE', y=['discharge/30'], ax=ax[i])
    ax[i].set_title('year=' + str(year))
#ax.plot(df['DATE'], df['PRCP'])

# %%
fig, ax = plt.subplots(8,1, figsize=(5,40))
for i in range(7):
    year=2015+i
    summer_df_year = summer_df[summer_df['year']==year]
    summer_df_year.plot(x='DATE', y=['discharge_IndianCreek', 'discharge_SalmonRiver/100','discharge_SuckerCreek'], ax=ax[i])
    ax[i].set_title('year=' + str(year))
#ax.plot(df['DATE'], df['PRCP'])

# %%
summer_df.corr()
# Out:
#                                     PRCP_happycamp  TMAX_happycamp  \
# PRCP_happycamp                            1.000000       -0.383416
# TMAX_happycamp                           -0.383416        1.000000
# TMIN_happycamp                           -0.034638        0.721922
# TOBS_happycamp                           -0.035334        0.704394
# PRCP_orleans                                   NaN             NaN
# PRCP_salmonriver                          0.756871       -0.408658
# PRCP_cavejunction                         0.825833       -0.442851
# discharge_IndianCreek                     0.691605       -0.472892
# gage_ht_IndianCreek                       0.588308       -0.517544
# discharge_IndianCreek_daily_change        0.110883        0.144711
# discharge_SalmonRiver                    -0.030195        0.135999
# gage_ht_SalmonRiver                            NaN             NaN
# discharge_SalmonRiver_daily_change        0.254259       -0.303090
# discharge_SuckerCreek                     0.642476       -0.469216
# gage_ht_SuckerCreek                       0.580295       -0.502768
# discharge_SuckerCreek_daily_change        0.217154        0.095654
# year                                     -0.104907        0.116621
# month                                     0.182001       -0.834580
# day                                       0.096885        0.006964
# discharge/30                              0.691605       -0.472892
# discharge_SalmonRiver/100                -0.030195        0.135999
#
#                                     TMIN_happycamp  TOBS_happycamp  \
# PRCP_happycamp                           -0.034638       -0.035334
# TMAX_happycamp                            0.721922        0.704394
# TMIN_happycamp                            1.000000        0.971402
# TOBS_happycamp                            0.971402        1.000000
# PRCP_orleans                                   NaN             NaN
# PRCP_salmonriver                         -0.106069       -0.093114
# PRCP_cavejunction                        -0.092962       -0.090220
# discharge_IndianCreek                    -0.097779       -0.088052
# gage_ht_IndianCreek                      -0.113998       -0.121691
# discharge_IndianCreek_daily_change        0.047525        0.008900
# discharge_SalmonRiver                     0.262447        0.283812
# gage_ht_SalmonRiver                            NaN             NaN
# discharge_SalmonRiver_daily_change       -0.205433       -0.195437
# discharge_SuckerCreek                    -0.085686       -0.084621
# gage_ht_SuckerCreek                      -0.099829       -0.112264
# discharge_SuckerCreek_daily_change        0.031318        0.005245
# year                                      0.136322        0.214413
# month                                    -0.809016       -0.787748
# day                                       0.011465       -0.069546
# discharge/30                             -0.097779       -0.088052
# discharge_SalmonRiver/100                 0.262447        0.283812
#
#                                     PRCP_orleans  PRCP_salmonriver  \
# PRCP_happycamp                               NaN          0.756871
# TMAX_happycamp                               NaN         -0.408658
# TMIN_happycamp                               NaN         -0.106069
# TOBS_happycamp                               NaN         -0.093114
# PRCP_orleans                                 NaN               NaN
# PRCP_salmonriver                             NaN          1.000000
# PRCP_cavejunction                            NaN          0.816027
# discharge_IndianCreek                        NaN          0.576646
# gage_ht_IndianCreek                          NaN          0.502475
# discharge_IndianCreek_daily_change           NaN          0.356112
# discharge_SalmonRiver                        NaN         -0.026775
# gage_ht_SalmonRiver                          NaN          0.349545
# discharge_SalmonRiver_daily_change           NaN          0.182725
# discharge_SuckerCreek                        NaN          0.551740
# gage_ht_SuckerCreek                          NaN          0.506455
# discharge_SuckerCreek_daily_change           NaN          0.370359
# year                                         NaN         -0.040087
# month                                        NaN          0.257323
# day                                          NaN          0.095015
# discharge/30                                 NaN          0.576646
# discharge_SalmonRiver/100                    NaN         -0.026775
#
#                                     PRCP_cavejunction  discharge_IndianCreek  \
# PRCP_happycamp                               0.825833               0.691605
# TMAX_happycamp                              -0.442851              -0.472892
# TMIN_happycamp                              -0.092962              -0.097779
# TOBS_happycamp                              -0.090220              -0.088052
# PRCP_orleans                                      NaN                    NaN
# PRCP_salmonriver                             0.816027               0.576646
# PRCP_cavejunction                            1.000000               0.636609
# discharge_IndianCreek                        0.636609               1.000000
# gage_ht_IndianCreek                          0.571748               0.911562
# discharge_IndianCreek_daily_change           0.535373               0.247889
# discharge_SalmonRiver                       -0.090040               0.146525
# gage_ht_SalmonRiver                          0.317805               0.308688
# discharge_SalmonRiver_daily_change           0.199603               0.167938
# discharge_SuckerCreek                        0.610072               0.965387
# gage_ht_SuckerCreek                          0.576849               0.887516
# discharge_SuckerCreek_daily_change           0.556999               0.265628
# year                                        -0.084808              -0.031943
# month                                        0.255010               0.319604
# day                                          0.089800               0.098902
# discharge/30                                 0.636609               1.000000
# discharge_SalmonRiver/100                   -0.090040               0.146525
#
#                                     gage_ht_IndianCreek  \
# PRCP_happycamp                                 0.588308
# TMAX_happycamp                                -0.517544
# TMIN_happycamp                                -0.113998
# TOBS_happycamp                                -0.121691
# PRCP_orleans                                        NaN
# PRCP_salmonriver                               0.502475
# PRCP_cavejunction                              0.571748
# discharge_IndianCreek                          0.911562
# gage_ht_IndianCreek                            1.000000
# discharge_IndianCreek_daily_change             0.130726
# discharge_SalmonRiver                          0.161674
# gage_ht_SalmonRiver                            0.389525
# discharge_SalmonRiver_daily_change             0.120809
# discharge_SuckerCreek                          0.916069
# gage_ht_SuckerCreek                            0.967130
# discharge_SuckerCreek_daily_change             0.145579
# year                                          -0.279518
# month                                          0.302063
# day                                            0.086855
# discharge/30                                   0.911562
# discharge_SalmonRiver/100                      0.161674
#
#                                     discharge_IndianCreek_daily_change  ...  \
# PRCP_happycamp                                                0.110883  ...
# TMAX_happycamp                                                0.144711  ...
# TMIN_happycamp                                                0.047525  ...
# TOBS_happycamp                                                0.008900  ...
# PRCP_orleans                                                       NaN  ...
# PRCP_salmonriver                                              0.356112  ...
# PRCP_cavejunction                                             0.535373  ...
# discharge_IndianCreek                                         0.247889  ...
# gage_ht_IndianCreek                                           0.130726  ...
# discharge_IndianCreek_daily_change                            1.000000  ...
# discharge_SalmonRiver                                        -0.043119  ...
# gage_ht_SalmonRiver                                          -0.146597  ...
# discharge_SalmonRiver_daily_change                           -0.011072  ...
# discharge_SuckerCreek                                         0.174434  ...
# gage_ht_SuckerCreek                                           0.118692  ...
# discharge_SuckerCreek_daily_change                            0.909681  ...
# year                                                         -0.005540  ...
# month                                                         0.011828  ...
# day                                                           0.015489  ...
# discharge/30                                                  0.247889  ...
# discharge_SalmonRiver/100                                    -0.043119  ...
#
#                                     gage_ht_SalmonRiver  \
# PRCP_happycamp                                      NaN
# TMAX_happycamp                                      NaN
# TMIN_happycamp                                      NaN
# TOBS_happycamp                                      NaN
# PRCP_orleans                                        NaN
# PRCP_salmonriver                               0.349545
# PRCP_cavejunction                              0.317805
# discharge_IndianCreek                          0.308688
# gage_ht_IndianCreek                            0.389525
# discharge_IndianCreek_daily_change            -0.146597
# discharge_SalmonRiver                          0.999744
# gage_ht_SalmonRiver                            1.000000
# discharge_SalmonRiver_daily_change             0.209280
# discharge_SuckerCreek                          0.425468
# gage_ht_SuckerCreek                            0.484364
# discharge_SuckerCreek_daily_change            -0.092971
# year                                                NaN
# month                                               NaN
# day                                           -0.590552
# discharge/30                                   0.308688
# discharge_SalmonRiver/100                      0.999744
#
#                                     discharge_SalmonRiver_daily_change  \
# PRCP_happycamp                                                0.254259
# TMAX_happycamp                                               -0.303090
# TMIN_happycamp                                               -0.205433
# TOBS_happycamp                                               -0.195437
# PRCP_orleans                                                       NaN
# PRCP_salmonriver                                              0.182725
# PRCP_cavejunction                                             0.199603
# discharge_IndianCreek                                         0.167938
# gage_ht_IndianCreek                                           0.120809
# discharge_IndianCreek_daily_change                           -0.011072
# discharge_SalmonRiver                                        -0.521237
# gage_ht_SalmonRiver                                           0.209280
# discharge_SalmonRiver_daily_change                            1.000000
# discharge_SuckerCreek                                         0.135559
# gage_ht_SuckerCreek                                           0.093276
# discharge_SuckerCreek_daily_change                            0.046167
# year                                                         -0.033863
# month                                                         0.313646
# day                                                           0.114331
# discharge/30                                                  0.167938
# discharge_SalmonRiver/100                                    -0.521237
#
#                                     discharge_SuckerCreek  \
# PRCP_happycamp                                   0.642476
# TMAX_happycamp                                  -0.469216
# TMIN_happycamp                                  -0.085686
# TOBS_happycamp                                  -0.084621
# PRCP_orleans                                          NaN
# PRCP_salmonriver                                 0.551740
# PRCP_cavejunction                                0.610072
# discharge_IndianCreek                            0.965387
# gage_ht_IndianCreek                              0.916069
# discharge_IndianCreek_daily_change               0.174434
# discharge_SalmonRiver                            0.211021
# gage_ht_SalmonRiver                              0.425468
# discharge_SalmonRiver_daily_change               0.135559
# discharge_SuckerCreek                            1.000000
# gage_ht_SuckerCreek                              0.926211
# discharge_SuckerCreek_daily_change               0.230152
# year                                            -0.114916
# month                                            0.284517
# day                                              0.097841
# discharge/30                                     0.965387
# discharge_SalmonRiver/100                        0.211021
#
#                                     gage_ht_SuckerCreek  \
# PRCP_happycamp                                 0.580295
# TMAX_happycamp                                -0.502768
# TMIN_happycamp                                -0.099829
# TOBS_happycamp                                -0.112264
# PRCP_orleans                                        NaN
# PRCP_salmonriver                               0.506455
# PRCP_cavejunction                              0.576849
# discharge_IndianCreek                          0.887516
# gage_ht_IndianCreek                            0.967130
# discharge_IndianCreek_daily_change             0.118692
# discharge_SalmonRiver                          0.257683
# gage_ht_SalmonRiver                            0.484364
# discharge_SalmonRiver_daily_change             0.093276
# discharge_SuckerCreek                          0.926211
# gage_ht_SuckerCreek                            1.000000
# discharge_SuckerCreek_daily_change             0.155855
# year                                          -0.375401
# month                                          0.291002
# day                                            0.079047
# discharge/30                                   0.887516
# discharge_SalmonRiver/100                      0.257683
#
#                                     discharge_SuckerCreek_daily_change  \
# PRCP_happycamp                                                0.217154
# TMAX_happycamp                                                0.095654
# TMIN_happycamp                                                0.031318
# TOBS_happycamp                                                0.005245
# PRCP_orleans                                                       NaN
# PRCP_salmonriver                                              0.370359
# PRCP_cavejunction                                             0.556999
# discharge_IndianCreek                                         0.265628
# gage_ht_IndianCreek                                           0.145579
# discharge_IndianCreek_daily_change                            0.909681
# discharge_SalmonRiver                                        -0.041206
# gage_ht_SalmonRiver                                          -0.092971
# discharge_SalmonRiver_daily_change                            0.046167
# discharge_SuckerCreek                                         0.230152
# gage_ht_SuckerCreek                                           0.155855
# discharge_SuckerCreek_daily_change                            1.000000
# year                                                         -0.009910
# month                                                         0.017567
# day                                                           0.028444
# discharge/30                                                  0.265628
# discharge_SalmonRiver/100                                    -0.041206
#
#                                             year         month           day  \
# PRCP_happycamp                     -1.049066e-01  1.820006e-01  9.688512e-02
# TMAX_happycamp                      1.166206e-01 -8.345798e-01  6.964339e-03
# TMIN_happycamp                      1.363222e-01 -8.090161e-01  1.146524e-02
# TOBS_happycamp                      2.144134e-01 -7.877477e-01 -6.954628e-02
# PRCP_orleans                                 NaN           NaN           NaN
# PRCP_salmonriver                   -4.008684e-02  2.573227e-01  9.501521e-02
# PRCP_cavejunction                  -8.480768e-02  2.550103e-01  8.979985e-02
# discharge_IndianCreek              -3.194339e-02  3.196040e-01  9.890162e-02
# gage_ht_IndianCreek                -2.795180e-01  3.020628e-01  8.685519e-02
# discharge_IndianCreek_daily_change -5.539994e-03  1.182804e-02  1.548946e-02
# discharge_SalmonRiver              -4.095633e-02 -3.473210e-01 -1.708382e-01
# gage_ht_SalmonRiver                          NaN           NaN -5.905522e-01
# discharge_SalmonRiver_daily_change -3.386291e-02  3.136462e-01  1.143308e-01
# discharge_SuckerCreek              -1.149160e-01  2.845174e-01  9.784054e-02
# gage_ht_SuckerCreek                -3.754005e-01  2.910019e-01  7.904684e-02
# discharge_SuckerCreek_daily_change -9.909745e-03  1.756725e-02  2.844364e-02
# year                                1.000000e+00 -7.672231e-15 -2.124234e-15
# month                              -7.672231e-15  1.000000e+00 -1.589799e-02
# day                                -2.124234e-15 -1.589799e-02  1.000000e+00
# discharge/30                       -3.194339e-02  3.196040e-01  9.890162e-02
# discharge_SalmonRiver/100          -4.095633e-02 -3.473210e-01 -1.708382e-01
#
#                                     discharge/30  discharge_SalmonRiver/100
# PRCP_happycamp                          0.691605                  -0.030195
# TMAX_happycamp                         -0.472892                   0.135999
# TMIN_happycamp                         -0.097779                   0.262447
# TOBS_happycamp                         -0.088052                   0.283812
# PRCP_orleans                                 NaN                        NaN
# PRCP_salmonriver                        0.576646                  -0.026775
# PRCP_cavejunction                       0.636609                  -0.090040
# discharge_IndianCreek                   1.000000                   0.146525
# gage_ht_IndianCreek                     0.911562                   0.161674
# discharge_IndianCreek_daily_change      0.247889                  -0.043119
# discharge_SalmonRiver                   0.146525                   1.000000
# gage_ht_SalmonRiver                     0.308688                   0.999744
# discharge_SalmonRiver_daily_change      0.167938                  -0.521237
# discharge_SuckerCreek                   0.965387                   0.211021
# gage_ht_SuckerCreek                     0.887516                   0.257683
# discharge_SuckerCreek_daily_change      0.265628                  -0.041206
# year                                   -0.031943                  -0.040956
# month                                   0.319604                  -0.347321
# day                                     0.098902                  -0.170838
# discharge/30                            1.000000                   0.146525
# discharge_SalmonRiver/100               0.146525                   1.000000
#
# [21 rows x 21 columns]

# %%
summer_df['discharge_IndianCreek'].diff(periods=1)
# Out:
# 181          NaN
# 182    -1.580208
# 183    -0.410417
# 184    -0.338542
# 185    -0.812500
#           ...
# 2521   -7.614583
# 2522    1.520833
# 2523   -7.812500
# 2524   -8.302083
# 2525   -7.416667
# Name: discharge_IndianCreek, Length: 1071, dtype: float64

# %%
i=0
summer_df['discharge_IndianCreek_daily_change'].corr(summer_df['PRCP_salmonriver'])
#sm.tsa.stattools.ccf(summer_df['discharge_IndianCreek_daily_change'], summer_df['PRCP_salmonriver'], adjusted=False)
# Out:
# 0.35611200230465195

# %%
for offset in range(20):
    print(summer_df.shift(offset)['discharge_IndianCreek_daily_change'].corr(summer_df['PRCP_salmonriver']))
#a=summer_df['discharge_IndianCreek_daily_change'][offset:]
#a.values
# Out:
# 0.35611200230465195
# 0.3032559267319386
# 0.15870291248145907
# 0.07185341374009069
# 0.07514693759220749
# 0.034436158296764476
# -0.01966015352460664
# 0.05935696514550741
# -0.019202709992553756
# 0.002723524800235964
# -0.012851779148995131
# 0.02826662897734529
# 0.0028692945220069586
# -0.005818952257702419
# 0.012192464359808527
# 0.07386299110697359
# 0.07978073872713337
# -0.009753581249845513
# -0.04707466742313414
# 0.0019753441758005486

# %%
summers_before=summer_df[summer_df.year<2020]
summers_after=summer_df[summer_df.year>2020]

# %%
for offset in range(20):   
    print(summers_before.shift(offset)['discharge_IndianCreek_daily_change'].corr(summers_before['PRCP_salmonriver']))
# Out:
# 0.354751766269514
# 0.30642836210979435
# 0.17959183798629635
# 0.05617187054561642
# 0.07793179333335229
# 0.016111211330195194
# -0.015333986470272173
# 0.0595155577759286
# -0.0204384810148345
# 0.01436339358351219
# -0.020820499338315316
# 0.027885164645223004
# 0.0028987993758538325
# -0.022959203409519194
# 0.01999937710386329
# 0.08152713585418826
# 0.08076386336426791
# -0.010593433304813122
# -0.06408535954334199
# 0.00925095014710136

# %%
for offset in range(20):   
    print(summers_after.shift(offset)['discharge_IndianCreek_daily_change'].corr(summers_after['PRCP_salmonriver']))
# Out:
# 0.5181637542973851
# 0.12174866482931772
# 0.1723940482023734
# 0.09883140826027681
# -0.04550427573387725
# 0.20230040136133406
# -0.06907715332567804
# 0.07519128777418213
# -0.039192213515298585
# -0.1012864039101431
# 0.02279449828071206
# 0.04162525936962509
# -0.0011893960687715877
# 0.14250269621324624
# -0.04836102023065091
# 0.06480975982029008
# 0.1354875073920514
# -0.012364432799734081
# 0.07174447471013516
# -0.06422590687053026

# %%
for offset in range(20):   
    print(summers_before.shift(offset)['discharge_SalmonRiver_daily_change'].corr(summers_before['PRCP_salmonriver']))
# Out:
# 0.18957707538965055
# 0.1659878061557127
# 0.08612391073502083
# 0.047157631812409395
# 0.053648438182565324
# 0.04273167135221412
# 0.0405785370835664
# 0.031134923913128755
# 0.04621371120851434
# 0.05295161367910087
# 0.07151256260604433
# 0.09758713745227583
# 0.05615087677213633
# 0.05031949616008094
# 0.07011916751477214
# 0.04656854478391869
# 0.02788359820045342
# 0.01503406487566153
# 0.022046144409476054
# 0.031540454159045876

# %%
for offset in range(20):   
    print(summers_after.shift(offset)['discharge_SalmonRiver_daily_change'].corr(summers_after['PRCP_salmonriver']))
# Out:
# 0.20841300578257657
# 0.18888000354214007
# 0.13198472878866413
# 0.11762865223837103
# 0.0946711710224636
# 0.08199647330568807
# 0.08421104683371543
# 0.07482803550713646
# 0.07054100556667865
# 0.13905147356820624
# 0.18279679155494474
# 0.14241098279355963
# 0.16384478556882076
# 0.16637983440695814
# 0.21527490261978835
# 0.20243062436208353
# 0.1544213908176363
# 0.1431892171759149
# 0.03304326047913267
# 0.011966190286053573

# %%
result = sm.ols(formula="discharge_IndianCreek_daily_change ~ PRCP_salmonriver", data=summer_df).fit()

# %%
result.params
# Out:
# Intercept          -6.750553
# PRCP_salmonriver    5.251846
# dtype: float64

# %%
def lag_reg(df, offset_max,dependent_var, independent_var):
    reg_string = dependent_var +' ~ ' + independent_var + '_0'
    lag_df = df[[dependent_var]]
    lag_df[independent_var+'_' + str(0)]=df.shift(0)[[independent_var]].values
    for offset in range(1,offset_max):
        lag_df[independent_var+'_' + str(offset)]=df.shift(-offset)[[independent_var]].values
        reg_string += ' + '+independent_var +'_' + str(offset)
    result = sm.ols(formula=reg_string, data=lag_df).fit()
    return result.params, result.rsquared

# %%
lag_reg(summer_df, 6, 'discharge_IndianCreek_daily_change','PRCP_salmonriver')
# Out:
# /tmp/ipykernel_81/1050527928.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lag_df[independent_var+'_' + str(0)]=df.shift(0)[[independent_var]].values
# /tmp/ipykernel_81/1050527928.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lag_df[independent_var+'_' + str(offset)]=df.shift(-offset)[[independent_var]].values
# (Intercept            -8.094952
#  PRCP_salmonriver_0    2.581547
#  PRCP_salmonriver_1    2.349512
#  PRCP_salmonriver_2    1.289906
#  PRCP_salmonriver_3   -0.535125
#  PRCP_salmonriver_4   -0.020682
#  PRCP_salmonriver_5   -0.341922
#  dtype: float64,
#  0.13111185115169666)

# %%
corr_coef_df = pd.DataFrame(range(6))
for river in ["SalmonRiver","IndianCreek","SuckerCreek"]:
    #print('discharge_' + river+'_daily_change')
    params, rsquared = lag_reg(summers_before, 6, 'discharge_' + river+'_daily_change','PRCP_salmonriver')
    #print(params)
    #print(rsquared)
    corr_coef_df[river + 'before']=numpy.array(params[1:])
    #plt.plot(range(6),params[1:])
    params, rsquared = lag_reg(summers_after, 6, 'discharge_' + river+'_daily_change','PRCP_salmonriver')
    #print(params)
    #print(rsquared)
    #plt.plot(range(6),params[1:])
    corr_coef_df[river + 'after']=numpy.array(params[1:])
# Out:
# /tmp/ipykernel_81/1050527928.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lag_df[independent_var+'_' + str(0)]=df.shift(0)[[independent_var]].values
# /tmp/ipykernel_81/1050527928.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lag_df[independent_var+'_' + str(offset)]=df.shift(-offset)[[independent_var]].values

# %%
corr_coef_df.set_index(0,inplace=True)

# %%
corr_coef_df
# Out:
#    SalmonRiverbefore  SalmonRiverafter  IndianCreekbefore  IndianCreekafter  \
# 0
# 0          11.662161          5.506862           2.431941          9.737499
# 1           6.724858          3.447740           2.243228          0.268228
# 2          -0.366706          2.949894           2.107673         -0.628461
# 3          -2.021645          6.060526          -0.957511         -0.733798
# 4          -0.502262          5.345904           0.206095         -3.676584
# 5           1.090265          3.073373          -0.501961          4.345181
#
#    SuckerCreekbefore  SuckerCreekafter
# 0
# 0           1.417804          2.965855
# 1           0.777622         -0.850375
# 2           0.624975         -0.122769
# 3          -0.227723         -0.227424
# 4           0.141015         -1.263715
# 5          -0.324341          1.756456

# %%
corr_coef_df.plot()
# Out:
# <AxesSubplot:xlabel='0'>

# %%
fig, ax = plt.subplots(8,1, figsize=(5,40))
summer_df
for i in range(7):
    year=2015+i
    summer_df_year = summer_df[summer_df['year']==year]
    summer_df_year.plot(x='DATE', y=['PRCP_salmonriver','discharge_SalmonRiver/100'], ax=ax[i])
    ax[i].set_title('year=' + str(year))
#ax.plot(df['DATE'], df['PRCP'])

# %%
df=summers_before
offset_max=6
river="IndianCreek"
dependent_var='discharge_' + river+'_daily_change'
independent_var='PRCP_salmonriver'
reg_string = dependent_var +' ~ discharge_SalmonRiver_daily_change + ' + independent_var + '_0'
lag_df = df[[dependent_var, 'discharge_SalmonRiver_daily_change']]
lag_df[independent_var+'_' + str(0)]=df.shift(0)[[independent_var]].values
for offset in range(1,offset_max):
    lag_df[independent_var+'_' + str(offset)]=df.shift(-offset)[[independent_var]].values
    reg_string += ' + '+independent_var +'_' + str(offset)
result = sm.ols(formula=reg_string, data=lag_df).fit()
print(result.params)
print(result.rsquared)
plt.plot(result.params)
# Out:
# Intercept                            -8.545748
# discharge_SalmonRiver_daily_change    0.001687
# PRCP_salmonriver_0                    2.412265
# PRCP_salmonriver_1                    2.231883
# PRCP_salmonriver_2                    2.108292
# PRCP_salmonriver_3                   -0.954100
# PRCP_salmonriver_4                    0.206943
# PRCP_salmonriver_5                   -0.503801
# dtype: float64
# 0.14973709929865797
# /tmp/ipykernel_81/2480837999.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lag_df[independent_var+'_' + str(0)]=df.shift(0)[[independent_var]].values
# /tmp/ipykernel_81/2480837999.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lag_df[independent_var+'_' + str(offset)]=df.shift(-offset)[[independent_var]].values

# %%
df=summers_after
offset_max=6
river="IndianCreek"
dependent_var='discharge_' + river+'_daily_change'
independent_var='PRCP_salmonriver'
reg_string = dependent_var +' ~ discharge_SalmonRiver_daily_change + ' + independent_var + '_0'
lag_df = df[[dependent_var, 'discharge_SalmonRiver_daily_change']]
lag_df[independent_var+'_' + str(0)]=df.shift(0)[[independent_var]].values
for offset in range(1,offset_max):
    lag_df[independent_var+'_' + str(offset)]=df.shift(-offset)[[independent_var]].values
    reg_string += ' + '+independent_var +'_' + str(offset)
result = sm.ols(formula=reg_string, data=lag_df).fit()
print(result.params)
print(result.rsquared)
# Out:
# /tmp/ipykernel_81/1129516749.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lag_df[independent_var+'_' + str(0)]=df.shift(0)[[independent_var]].values
# /tmp/ipykernel_81/1129516749.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lag_df[independent_var+'_' + str(offset)]=df.shift(-offset)[[independent_var]].values
# Intercept                            -16.053246
# discharge_SalmonRiver_daily_change    -0.137186
# PRCP_salmonriver_0                    10.492963
# PRCP_salmonriver_1                     0.741210
# PRCP_salmonriver_2                    -0.223777
# PRCP_salmonriver_3                     0.097621
# PRCP_salmonriver_4                    -2.943201
# PRCP_salmonriver_5                     4.766805
# dtype: float64
# 0.3764294202348526

# %%
fig, ax = plt.subplots(7,1, figsize=(5,40))
for i in range(7):
    year=2015+i
    summer_df_year = summer_df[summer_df['year']==year]
    summer_df_year['discharge_IndianCreek_daily_change/10']= summer_df['discharge_IndianCreek_daily_change']/10
    summer_df_year.plot(x='DATE', y=['discharge_IndianCreek_daily_change/10','PRCP_salmonriver'], ax=ax[i])
    ax[i].set_title('year=' + str(year))
#ax.plot(df['DATE'], df['PRCP'])
# Out:
# /tmp/ipykernel_81/2264175459.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_IndianCreek_daily_change/10']= summer_df['discharge_IndianCreek_daily_change']/10
# /tmp/ipykernel_81/2264175459.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_IndianCreek_daily_change/10']= summer_df['discharge_IndianCreek_daily_change']/10
# /tmp/ipykernel_81/2264175459.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_IndianCreek_daily_change/10']= summer_df['discharge_IndianCreek_daily_change']/10
# /tmp/ipykernel_81/2264175459.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_IndianCreek_daily_change/10']= summer_df['discharge_IndianCreek_daily_change']/10
# /tmp/ipykernel_81/2264175459.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_IndianCreek_daily_change/10']= summer_df['discharge_IndianCreek_daily_change']/10
# /tmp/ipykernel_81/2264175459.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_IndianCreek_daily_change/10']= summer_df['discharge_IndianCreek_daily_change']/10
# /tmp/ipykernel_81/2264175459.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_IndianCreek_daily_change/10']= summer_df['discharge_IndianCreek_daily_change']/10

# %%
fig, ax = plt.subplots(7,1, figsize=(5,40))
for i in range(7):
    year=2015+i
    summer_df_year = summer_df[summer_df['year']==year]
    summer_df_year['discharge_SalmonRiver_daily_change/100']= summer_df['discharge_SalmonRiver_daily_change']/100
    summer_df_year.plot(x='DATE', y=['discharge_SalmonRiver_daily_change/100','PRCP_salmonriver'], ax=ax[i])
    ax[i].set_title('year=' + str(year))
#ax.plot(df['DATE'], df['PRCP'])
# Out:
# /tmp/ipykernel_81/1603999197.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_SalmonRiver_daily_change/100']= summer_df['discharge_SalmonRiver_daily_change']/100
# /tmp/ipykernel_81/1603999197.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_SalmonRiver_daily_change/100']= summer_df['discharge_SalmonRiver_daily_change']/100
# /tmp/ipykernel_81/1603999197.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_SalmonRiver_daily_change/100']= summer_df['discharge_SalmonRiver_daily_change']/100
# /tmp/ipykernel_81/1603999197.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_SalmonRiver_daily_change/100']= summer_df['discharge_SalmonRiver_daily_change']/100
# /tmp/ipykernel_81/1603999197.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_SalmonRiver_daily_change/100']= summer_df['discharge_SalmonRiver_daily_change']/100
# /tmp/ipykernel_81/1603999197.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_SalmonRiver_daily_change/100']= summer_df['discharge_SalmonRiver_daily_change']/100
# /tmp/ipykernel_81/1603999197.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_df_year['discharge_SalmonRiver_daily_change/100']= summer_df['discharge_SalmonRiver_daily_change']/100

# %%
summer_df.plot.scatter(x='PRCP_happycamp', y='PRCP_salmonriver')
# Out:
# <AxesSubplot:xlabel='PRCP_happycamp', ylabel='PRCP_salmonriver'>
